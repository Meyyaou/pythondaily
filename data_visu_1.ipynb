# %% [markdown]
# <a href="https://colab.research.google.com/github/Meyyaou/pythondaily/blob/main/data_visu_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#pour importer .xls
data= pd.read_excel("titanic3 (3).xls")
#returns a dataframe

#pour importer .csv
#pd.read_csv()
#pour importer .json
#pd.read_json()

#pour html read_html() pour sql read_sql()

# %%
#dimensions -> row, col
data.shape
#to see col
data.columns
#to see 5 by def first rows
#data.head()
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
#we drop les col non utiles=> drop([list non ord des cols], axis = (col/rows?))
data=data.drop(['name', 'ticket','sibsp', 'parch', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'], axis=1)
#pour les fct qui modif le df ya un equivalent pour stocker dans le df init
#data.drop(['name'], inplace=True)

# %%
data.head()
# Out:
#    pclass  survived     sex      age
# 0       1         1  female  29.0000
# 1       1         1    male   0.9167
# 2       1         0  female   2.0000
# 3       1         0    male  30.0000
# 4       1         0  female  25.0000

# %%
#basic stats
data.describe()
#age :> donnes manquantes when you see count
# Out:
#             pclass     survived          age
# count  1309.000000  1309.000000  1046.000000
# mean      2.294882     0.381971    29.881135
# std       0.837836     0.486055    14.413500
# min       1.000000     0.000000     0.166700
# 25%       2.000000     0.000000    21.000000
# 50%       3.000000     0.000000    28.000000
# 75%       3.000000     1.000000    39.000000
# max       3.000000     1.000000    80.000000

# %%
#2 sols s'offrent: complete par def
#data.fillna(data['age'].mean())
#ou drop les lignes ou les données manquent
data=data.dropna(axis=0)

# %%
data.describe()
# Out:
#             pclass     survived          age
# count  1046.000000  1046.000000  1046.000000
# mean      2.207457     0.408222    29.881135
# std       0.841497     0.491740    14.413500
# min       1.000000     0.000000     0.166700
# 25%       1.000000     0.000000    21.000000
# 50%       2.000000     0.000000    28.000000
# 75%       3.000000     1.000000    39.000000
# max       3.000000     1.000000    80.000000

# %%
#know the val of ppl in class 1/2/3
data['pclass'].value_counts()
# Out:
# pclass
# 3    501
# 1    284
# 2    261
# Name: count, dtype: int64

# %%
#using matplotlib
data['pclass'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='pclass'>

# %%
data['age'].hist()
# Out:
# <Axes: >

# %%
data.groupby(['sex', 'pclass']).mean()
# Out:
#                survived        age
# sex    pclass
# female 1       0.962406  37.037594
#        2       0.893204  27.499191
#        3       0.473684  22.185307
# male   1       0.350993  41.029250
#        2       0.145570  30.815401
#        3       0.169054  25.962273
